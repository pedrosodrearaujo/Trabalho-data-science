# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrosodrearaujo/Trabalho-data-science/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Nome: Pedro Henrique Sodré Araujo 
#Ra: 2111050

# %% [markdown]
# Neste trabalho farei uma análise sobre os números de abate de animais bovinos e suínos no segundo trimestre de 2022.
# Obs: eu importei a tabela oficial do IBGE e com os dados dela fiz uma outra tabela para analisar a região centro-oeste específicamente.

# %%
import pandas as pd
import numpy as np
import statistics
import matplotlib.pyplot as plt
from numpy import *

# %%
planilha = pd.read_excel("/content/base de dados trabalho programaçao (1).xlsx")
display (planilha)
# Out:
#    Abate - Número de informantes, quantidade de animais abatidos e peso total das carcaças, por tipo de rebanho, segundo as Unidades da Federação  \
# 0                                   2º trimestre 2022
# 1                      Brasil e Unidades da Federação
# 2                                                 NaN
# 3                                              Brasil
# 4                                               Norte
# 5                                            Rondônia
# 6                                                Acre
# 7                                            Amazonas
# 8                                             Roraima
# 9                                                Pará
# 10                                              Amapá
# 11                                          Tocantins
# 12                                           Nordeste
# 13                                           Maranhão
# 14                                              Piauí
# ...

# %%
planilha = pd.read_excel("/content/dados2 programaçao.xlsx")
display (planilha)
# Out:
#   Quantidade de animais suínos e bovinos abatidos ( cabeça) no 2º trimestre de 2022  \
# 0                                                NaN
# 1                                 Mato grosso do sul
# 2                                       Mato grosso
# 3                                              Goiás
# 4                                                 DF
#
#   Unnamed: 1 Unnamed: 2
# 0    Bovinos     Suínos
# 1     832045     676409
# 2    1110505     684038
# 3     712111     531286
# 4          X      30580

# %%
TotalAbateBovino = planilha['Bovinos'].sum()
print(TotalAbateBovino)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-5d3f0a36e167> in <module>
# ----> 1 TotalAbateBovino = planilha['Unnamed: 1'].sum()
#       2 print(TotalAbateBovino)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10706             **kwargs,
#   10707         ):
# > 10708             return NDFrame.sum(
#   10709                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   10710             )
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10444         **kwargs,
#   10445     ):
# > 10446         return self._min_count_stat_function(
#   10447             "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10448         )
#
# ...

# %% [markdown]
# Total abate bovino no centro-oeste = 2.654.661

# %% [markdown]
# Total abate suíno no centro-oeste = 1.922.313

# %%
MediaBovinos = planilha["bovinos"].mean()
print(Mediabovinos)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bovinos'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# Média bovinos na região centro-oeste = 663.665,25

# %% [markdown]
# Média suínos centro-oeste = 480.578,25

# %% [markdown]
# Podemos concluir que o abate bovino é superior ao suíno no centro-oeste, porém não muito como alguns devem imaginar. E a média de abates teve uma diferença de quase um terço dos bois para porcos.

# %% [markdown]
# Professor, eu não consegui concertar os erros dos códigos de soma e média. Eu ja tinha feito antes uma análise parecida e os códigos estavam iguais e deu certo, então não entendi como concertar os erros dos códigos desse trabalho... E por isso fiz as somas e médias manualmente e coloquei em baixo.
